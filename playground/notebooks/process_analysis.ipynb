# %%
from IPython.display import display
import pandas as pd
from playground.db_engine import create_db_engine
from playground.process_analysis.status_transition_vistualizer import StatusTransitionVisualizer
from playground.process_analysis.status_transition_graph import StatusTransitionGraph

from datetime import datetime

DB_URL = "mysql://merico:merico@127.0.0.1:3306/lake"

df = pd.DataFrame([
    {
        "issue_key": "ISSUE-1",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "To Do",
        "from_value": "TODO",
        "original_to_value": "Ready",
        "to_value": "TODO",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-02 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
    {
        "issue_key": "ISSUE-1",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "Ready",
        "from_value": "TODO",
        "original_to_value": "In Progress",
        "to_value": "IN_PROGRESS",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-04 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
    {
        "issue_key": "ISSUE-1",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "In Progress",
        "from_value": "IN_PROGRESS",
        "original_to_value": "Done",
        "to_value": "DONE",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-05 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
    {
        "issue_key": "ISSUE-2",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "To Do",
        "from_value": "TODO",
        "original_to_value": "Ready",
        "to_value": "TODO",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-02 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
    {
        "issue_key": "ISSUE-2",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "To Do",
        "from_value": "TODO",
        "original_to_value": "In Progress",
        "to_value": "IN_PROGRESS",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-03 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
    {
        "issue_key": "ISSUE-2",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "In Progress",
        "from_value": "IN_PROGRESS",
        "original_to_value": "To Do",
        "to_value": "TODO",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-07 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
    {
        "issue_key": "ISSUE-2",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "To Do",
        "from_value": "TODO",
        "original_to_value": "Won't Fix",
        "to_value": "DONE",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-08 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
    {
        "issue_key": "ISSUE-2",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "Won't Fix",
        "from_value": "DONE",
        "original_to_value": "In Progress",
        "to_value": "IN_PROGRESS",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-17 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
    {
        "issue_key": "ISSUE-2",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "In Progress",
        "from_value": "IN_PROGRESS",
        "original_to_value": "Done",
        "to_value": "DONE",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-18 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
    {
        "issue_key": "ISSUE-3",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "To Do",
        "from_value": "TODO",
        "original_to_value": "Ready",
        "to_value": "TODO",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-07 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
    {
        "issue_key": "ISSUE-4",
        "created_date": pd.Timestamp(datetime.strptime("2021-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")),
        "original_from_value": "To Do",
        "from_value": "TODO",
        "original_to_value": "Won't Fix",
        "to_value": "DONE",
        "changed_date": pd.Timestamp(datetime.strptime("2021-01-05 00:00:00", "%Y-%m-%d %H:%M:%S"))
    },
])

# process_graph = ProcessGraph.from_database(create_db_engine(DB_URL))
process_graph = StatusTransitionGraph.from_data_frame(df)
svg = StatusTransitionVisualizer.visualize(process_graph, threshold=0.99)
display(svg)
